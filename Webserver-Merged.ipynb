# %%
# webserver.py
from flask import Flask, jsonify
import psycopg2
from psycopg2.extras import RealDictCursor
from config import db_name, user, password, host

app = Flask(__name__)

def get_db_connection():
    try:
        conn = psycopg2.connect(
            dbname=db_name,
            user=user,
            password=password,
            host=host
        )
        return conn
    except psycopg2.Error as e:
        app.logger.error(f"Error connecting to database: {e}")
        return None


@app.route('/map', methods=['GET'])
def get_landslide_data():
    conn = get_db_connection()
    cursor = conn.cursor(cursor_factory=RealDictCursor)
    cursor.execute('''
        SELECT
            cod_reg,
            cod_rip,
            COD_PROV,
            ar_kmq,
            nome,
            uid,
            ar_fr_p3p4,
            ar_fr_p4,
            ar_fr_p3,
            ar_fr_p2,
            pop_fr_p4,
            pop_fr_p3,
            pop_fr_p2,
            ed_fr_p4,
            ed_fr_p3,
            ed_fr_p2,
            ar_frp3p4p,
            popfrp3p4p,
            ed_fr_p3p4,
            edfrp3p4p,
            ST_AsText(ST_SnapToGrid(geometry, 0.001)) as geom_wkt  -- Adjust 0.001 for your desired precision
        FROM dataset
    ''')
    data = cursor.fetchall()
    cursor.close()
    conn.close()
    return jsonify(data)


@app.route('/landslides/surface', methods=['GET'])
def get_landslides():
    conn = get_db_connection()
    if conn is None:
        return jsonify({"error": "Database connection error"}), 500
    
    try:
        cursor = conn.cursor(cursor_factory=RealDictCursor)
        cursor.execute("SELECT ar_kmq, nome, ar_fr_p3p4, ar_fr_p2, ar_fr_p1, ar_fr_p3, ar_fr_p4, ar_fr_aa, ar_frp4_p, ar_frp3_p, ar_frp2_p,ar_frp1_p, ar_fraa_p, ar_frp3p4p FROM dataset;")
        landslides = cursor.fetchall()
        cursor.close()
        conn.close()
        return jsonify(landslides)
    except psycopg2.Error as e:
        app.logger.error(f"Error executing SQL query: {e}")
        return jsonify({"error": "Internal Server Error"}), 500

@app.route('/landslides/map', methods=['GET'])
def get_landslides_map():
    conn = get_db_connection()
    if conn is None:
        return jsonify({"error": "Database connection error"}), 500
    
    try:
        cursor = conn.cursor(cursor_factory=RealDictCursor)
        cursor.execute("SELECT ar_kmq, nome, ar_fr_p3p4, ar_fr_p2, ar_fr_p1, ar_fr_p3, ar_fr_p4, ar_fr_aa, ar_frp4_p, ar_frp3_p, ar_frp2_p, ar_frp1_p, ar_fraa_p, ar_frp3p4p, pop_fr_p2, pop_fr_p1, pop_fr_p3, pop_fr_p4, pop_fr_aa, popfrp4_p, popfrp3_p, popfrp2_p, popfrp1_p, popfrp3p4p, popfr_p3p4, popfraa_p, ST_AsText(geometry) AS geometry_wkt FROM dataset;")
        landslides_map = cursor.fetchall()
        
        for row in landslides_map:
            wkt_data = row['geometry_wkt']
            try:
                row['geometry'] = wkt_data  # Directly assign the WKT data
            except Exception as e:
                app.logger.error(f"Error processing WKT data: {e}")
                row['geometry'] = None  # Handle or log this error as needed
            del row['geometry_wkt']

        cursor.close()
        conn.close()
        return jsonify(landslides_map)
    except psycopg2.Error as e:
        app.logger.error(f"Error executing SQL query: {e}")
        return jsonify({"error": "Internal Server Error"}), 500

@app.route('/landslides/population', methods=['GET'])
def get_landslides_population():
    conn = get_db_connection()
    if conn is None:
        return jsonify({"error": "Database connection error"}), 500
    
    try:
        cursor = conn.cursor(cursor_factory=RealDictCursor)
        cursor.execute("SELECT ar_kmq,pop_fr_p2, pop_fr_p1, pop_fr_p3, pop_fr_p4, pop_fr_aa, popfrp4_p, popfrp3_p, popfrp2_p, popfrp1_p, popfrp3p4p, popfr_p3p4, popfraa_p, nome FROM dataset;")
        landslides_population = cursor.fetchall()
        cursor.close()
        conn.close()
        return jsonify(landslides_population)
    except psycopg2.Error as e:
        app.logger.error(f"Error executing SQL query: {e}")
        return jsonify({"error": "Internal Server Error"}), 500

if __name__ == '__main__':
    app.run(debug=True, host='127.0.0.1', port=5000, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [29/Jun/2024 19:40:00] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:40:00] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:40:15] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:40:15] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:40:18] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:40:20] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:40:27] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:40:29] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:40:31] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:40:33] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:40:37] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:40:39] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:40:43] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:40:50] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:41:06] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:41:06] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:41:08] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:41:18] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:41:19] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:41:26] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:41:26] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:41:28] "GET /map HTTP/1.1" 500 -
# 127.0.0.1 - - [29/Jun/2024 19:41:28] "Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:41:29] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:42:44] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:42:45] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:42:45] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:42:48] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:42:48] "GET /map HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1488, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1466, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 1463, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 872, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 870, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\flask\app.py", line 855, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_15544\2086474574.py", line 27, in get_landslide_data
#     cursor.execute('''
#   File "C:\Users\Asus\anaconda3\envs\se4g\Lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedColumn: column "ed_fr_p4" does not exist
# LINE 16:             ed_fr_p4,
#                      ^
# HINT:  Perhaps you meant to reference the column "dataset.ed_fr_p2" or the column "dataset.ed_fr_p1".
#
# 127.0.0.1 - - [29/Jun/2024 19:46:36] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:46:36] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:46:45] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:46:45] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:46:47] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:46:47] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:46:50] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:46:53] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:47:02] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:47:33] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:47:50] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:48:01] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:48:17] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:48:25] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:49:59] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:50:06] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:50:39] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:50:40] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:54:30] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:54:34] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:54:50] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:54:50] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 19:54:52] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:06:39] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:06:39] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:06:41] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:06:41] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:06:45] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:06:45] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:06:52] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:06:54] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:07:32] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:07:32] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:07:58] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:08:00] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:10:18] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:10:18] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:10:19] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:10:19] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:10:56] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:10:56] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:10:56] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:10:56] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:15:19] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:15:19] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:15:20] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:15:20] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:08] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:08] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:10] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:10] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:16] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:17] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:19] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:40] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:40] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:41] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:41] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:45] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:30:46] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:31:14] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:31:39] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:31:39] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:31:41] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:31:41] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:31:47] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:31:48] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:41:41] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:41:41] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:42:03] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:42:04] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:42:25] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:42:25] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:42:33] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:42:34] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:42:47] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:42:47] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:42:49] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:43:02] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:43:02] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:43:03] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:43:03] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:43:04] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:45] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:45] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:46] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:46] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:53] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:53] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:55] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:55] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:57] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:57] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:58] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:44:58] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:02] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:02] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:05] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:05] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:07] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:07] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:09] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:19] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:21] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:32] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:33] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:57] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:45:58] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:46:10] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:47:19] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:47:19] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:47:20] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:47:20] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:47:24] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:47:25] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:47:30] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:47:34] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:49:52] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:49:52] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:49:54] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:49:54] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:49:57] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:49:58] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:50:01] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:50:06] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:50:31] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:50:31] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:50:32] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:50:32] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:56:46] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:56:46] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:56:48] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:56:48] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:58:35] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:58:35] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:58:54] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:58:54] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:58:57] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:58:58] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:59:31] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 20:59:31] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:00:57] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:00:57] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:01:17] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:01:17] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:01:29] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:01:32] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:04:42] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:04:42] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:04:47] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:04:50] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:04:53] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:04:53] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:01] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:16] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:16] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:19] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:22] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:22] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:24] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:24] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:26] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:33] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:37] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:40] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:40] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:42] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:05:48] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:07:18] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:07:18] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:07:20] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:07:20] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:07:22] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:07:25] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:07:26] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:07:27] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:07:33] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:07:34] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:07:41] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:04] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:04] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:04] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:04] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:06] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:10] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:11] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:13] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:16] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:19] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:20] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:22] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:22] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:25] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:33] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:33] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:36] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:36] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:38] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:38] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:40] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:40] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:42] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:42] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:43] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:43] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:45] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:45] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:47] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:47] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:49] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:52] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:08:53] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:09:27] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:09:27] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:09:28] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:09:28] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:09:34] "GET /landslides/population HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:09:35] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:09:39] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:11:42] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:11:42] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:11:43] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:11:43] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:11:47] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:11:48] "GET /landslides/map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:12:13] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:12:13] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:12:13] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:12:13] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:12:18] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:12:22] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:12:25] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:12:27] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:12:28] "GET /landslides/surface HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Jun/2024 21:12:32] "GET /landslides/surface HTTP/1.1" 200 -
